# %%
import pandas as pd
import os

# %%
dir_data= '../parquet_datasets'
os.listdir(dir_data)
# Out:
# ['DANE_Codificación_Divipola.parquet',
#  'medicos_ips_servicios_corregido.parquet',
#  'nofetal2017_new.parquet',
#  'nofetal2018_new.parquet',
#  'proyecciones_poblacion_departamental_2018-2050.parquet',
#  'SIVIGILA_2016_PARQUET',
#  'SIVIGILA_2017_PARQUET',
#  'SIVIGILA_2018_PARQUET']

# %%
DANE_Codificación_Divipola=pd.read_parquet(f'{dir_data}/DANE_Codificación_Divipola.parquet')
DANE_Codificación_Divipola.head()
# Out:
#    Código Departamento  Código Municipio  Código Centro Poblado  \
# 0                    5              5001                5001000
# 1                    5              5001                5001001
# 2                    5              5001                5001004
# 3                    5              5001                5001009
# 4                    5              5001                5001010
#
#   Nombre Departamento Nombre Municipio Nombre Centro Poblado  \
# 0           ANTIOQUIA         MEDELLÍN              MEDELLÍN
# 1           ANTIOQUIA         MEDELLÍN              PALMITAS
# 2           ANTIOQUIA         MEDELLÍN           SANTA ELENA
# 3           ANTIOQUIA         MEDELLÍN             ALTAVISTA
# 4           ANTIOQUIA         MEDELLÍN           AGUAS FRÍAS
#
#   Tipo Centro Poblado   Longitud   Latitud Nombre Distrito  \
# 0  CABECERA MUNICIPAL -75.581713  6.246716            None
# 1      CENTRO POBLADO -75.690039  6.343341            None
# ...

# %%
medicos_ips_servicios_corregido=pd.read_parquet(f'{dir_data}/medicos_ips_servicios_corregido.parquet')
medicos_ips_servicios_corregido.head()
# Out:
#   depa_nombre muni_nombre  habi_codigo_habilitacion  numero_sede  \
# 0   Antioquia    MEDELLÍN                 500100003            1
# 1   Antioquia    MEDELLÍN                 500100008            1
# 2   Antioquia    MEDELLÍN                 500100010            1
# 3   Antioquia    MEDELLÍN                 500100012            1
# 4   Antioquia    MEDELLÍN                 500100012            1
#
#                     sede_nombre  \
# 0   BERNARDO  AGUDELO JARAMILLO
# 1     ANA CARMENZA POSADA ISAZA
# 2  JUAN CAMILO RESTREPO SALCEDO
# 3        INSTITUTO DEL CORAZON
# 4        INSTITUTO DEL CORAZON
#
#                                            direccion telefono  \
# 0                         CL 19A N° 44- 25 Cons 2301  3665349
# 1  CL  2 SUR # 46 - 55 CS 253 FASE II CLINICA LAS...  2687270
# 2                        DIAG 75B # 2A - 80 CONS 809     None
# 3                               CIRCULAR 73 N° 39-37  3207242
# ...

# %%
nofetal2017_new=pd.read_parquet(f'{dir_data}/nofetal2017_new.parquet')
nofetal2017_new.head()
# Out:
#    Unnamed: 0   COD_DPTO  COD_MUNIC             A_DEFUN         SIT_DEFUN  \
# 0           0   Putumayo        573  Cabecera municipal  Hospital/clínica
# 1           1   Putumayo        757  Cabecera municipal       Vía pública
# 2           2  Antioquia        250  Cabecera municipal  Hospital/clínica
# 3           3  Antioquia        240      Rural disperso       Vía pública
# 4           4      Cauca        532      Rural disperso       Vía pública
#
#   OTRSITIODE      COD_INST                                       NOM_INST  \
# 0             865730018501                   ESE HOSPITAL MARIA ANGELINES
# 1             867570002101              ESE HOSPITAL FRONTERIZO LA DORADA
# 2             052500213301      E.S.E. HOSPITLA NUESTRA SE?ORA DEL CARMEN
# 3             052400374401  EMPRESA SOCIAL DEL ESTADO HOSPITAL SAN RAFAEL
# 4             195320001201               E.S.E. HOSPITAL NIVEL I EL BORDO
#
# ...

# %%
nofetal2018_new=pd.read_parquet(f'{dir_data}/nofetal2018_new.parquet')
nofetal2018_new.head()
# Out:
#     COD_DPTO  COD_MUNIC             A_DEFUN         SIT_DEFUN OTRSITIODE  \
# 0     Caldas         50  Cabecera municipal       Vía pública
# 1    Caqueta        592  Cabecera municipal  Hospital/clínica
# 2     Caldas         13  Cabecera municipal   Casa /domicilio
# 3  Antioquia          1  Cabecera municipal   Casa /domicilio
# 4       Meta          1  Cabecera municipal  Hospital/clínica
#
#            TIPO_DEFUN   ANO    MES HORA MINUTOS  ... C_ANT22 C_ANT3 C_ANT32  \
# 0  Defunción no fetal  2018  Enero   15       5  ...
# 1  Defunción no fetal  2018  Enero    8      15  ...
# 2  Defunción no fetal  2018  Enero   10       0  ...
# 3  Defunción no fetal  2018  Enero   12      15  ...
# 4  Defunción no fetal  2018  Enero   11       0  ...    K388
#
#   C_PAT1 C_PAT2  C_BAS1 C_MCM1 CAUSA_667 IDPROFCER CAU_HOMOL
# 0                  I219              303         1        51
# 1   R011            E43              602         1        42
# ...

# %%
proyecciones_poblacion_departamental_2018_2050=pd.read_parquet(f'{dir_data}/proyecciones_poblacion_departamental_2018-2050.parquet')
proyecciones_poblacion_departamental_2018_2050.head()
# Out:
#    DP      DPNOM   AÑO                    ÁREA GEOGRÁFICA  Hombres_0  \
# 0   5  Antioquia  2018                 Cabecera Municipal      31398
# 1   5  Antioquia  2018  Centros Poblados y Rural Disperso      14488
# 2   5  Antioquia  2018                              Total      45886
# 3   5  Antioquia  2019                 Cabecera Municipal      32581
# 4   5  Antioquia  2019  Centros Poblados y Rural Disperso      14220
#
#    Hombres_1  Hombres_2  Hombres_3  Hombres_4  Hombres_5  ...  Total_94  \
# 0      31674      31916      32172      32460      32748  ...      1766
# 1      14314      14164      14027      13878      13742  ...       477
# 2      45988      46080      46199      46338      46490  ...      2243
# 3      32652      32860      33074      33261      33471  ...      1881
# 4      14033      13938      13829      13711      13603  ...       449
#
#    Total_95  Total_96  Total_97  Total_98  Total_99  Total_100 y más  \
# ...
